# %% [markdown]
# <a href="https://colab.research.google.com/github/ru-corporate/sandbox/blob/master/boo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Анализ бухгалтерской отчетности российских компаний
#
# [Евгений Погребняк](https://epogrebnyak.github.io/cv/), февраль 2019
#
# 1. Где находятся и что представляют из себя исходные данные?
# 2. Как их получить и преобразовать для удобного использования?
# 3. Какие задачи мы можем решать с помощью отчетности?
# 4. Открытые вопросы для будущей работы
#
# ### Рекомендуем ознакомиться
#
# -  [Структура проектов обработки данных](http://drivendata.github.io/cookiecutter-data-science)
# - [README](https://github.com/ru-corporate/sandbox/blob/master/README.md) репозитария ![ru-corporate/sandbox](https://https://avatars3.githubusercontent.com/u/42803215?s=200&v=4)

# %% [markdown]
# ## Исходные данные
#
#  | Цели раздела |
#  |------------------------|
#  | 1. Знать источник и структуру исходных данных |
#  | 2. Понимать использованный способ преобразования данных  в пакете `boo` |

# %% [markdown]
# Исходные данные [Росстат раскрывает за 2012-2017 гг.][gks].
#
# Примеры файлов:
#
# | Год          |  Компаний  | Размер файла (Мб) |
# |--------------|:----------:|:-----------------:|
# | [2012][2012] |   765 813  |        525        |
# | [2017][2017] | 2 358 756  |       1631        |
#
# [gks]: http://www.gks.ru/opendata/dataset?q=%D0%BE%D1%82%D1%87%D0%B5%D1%82%D0%BD%D0%BE%D1%81%D1%82%D1%8C+%D0%BE%D1%80%D0%B3%D0%B0%D0%BD%D0%B8%D0%B7%D0%B0%D1%86%D0%B8%D0%B9+&sort=score+desc%2C+metadata_modified+desc
# [2012]: http://www.gks.ru/opendata/dataset/7708234640-bdboo2012
# [2017]: http://www.gks.ru/opendata/dataset/7708234640-bdboo2017
#
# На аналогичных данных построены ряд бесплатных и платных сервисов по предоставлению данных, их можно использовать для проверок результатов.
#
# ### Плюсы
#
# - открытые данные
# - появляются новые версии за предыдущие года
# - данные становятся чище (например, нет "битых" строк с неправильным количеством значений)
# - с каждым годом увеличивается охват компаний
# - есть контакты ответственного лица, мейл и телефон
# - есть дублирующий сервис для запроса отчетности по ИНН
#
# ### Проблемы
#
# - заголовки отдельно от файла, названия переменных изначально не очень понятны
# - строки могут быть в разных единицах измерения (тыс. руб., млн руб.)
# - дублирование, отсутствующие и искаженные данные, компании-"призраки"
#
#
# ### Как преодолеть ограничения?
#
# - построить отчетености компании за несколько лет
# - дополнить отсутствующие компании
# - привязать компании к фактическим отраслям
# - ввести классификаторы (ОКВЭД, названия регионов)
# - связать с другими базами данных

# %% [markdown]
# ## Как использовать эти данные?
#
#
#  | Цели раздела |
#  |------------------------|
#  | 3. Описать возможных пользователей корпоративной отчетности и их потребности |

# %% [markdown]
# ### 1. Учебные задачи
#
# - бухучет: проверить тождества и связь между частями отчетности (баланс, P&L, CF)
# - финанализ: посчитать коэффициенты для оценки финансовой устойчивости и  эффективности
# - определить типы компаний по отчтености (торговые, производственные, холдинговые компании)
# - как проследить рост продаж, инвестиции в основной капитал, ситуации банкротства
# - связь фианнсовых показателей и показателей нацсчетов
#
# ### 2. Описательные задачи
#
# - рейтинги крупнейших предприятий (по аналогии с Эксперт, РБК, Коммерсант, Forbes)
# - отраслевые рейтинги
# - региональная экономика
#
# ### 3. Аналитические задачи
#
# - оценка компаний и кредитный риск
# - анализ налоговой нагрузки
# - развитие малого бизнеса
# - инвестиции в основной капитал
#
# ### 4. Исследовательские задачи
#
# - модели кредитного риска
# - анализ отраслевой концентрации
# - развитие региональной экономики
# - малоизвестные подотрасли
# - популярность названий предприятий

# %% [markdown]
# ## Хватит слов, посмотрим на данные!
#
#  | Цели раздела |
#  |------------------------|
#  | 4. Прочитать набор данных корпоративной отчетности в виде датафрейма `pandas` |
#  | 5. Понимать содержание переменных и связи между ними |

# %% [markdown]
# За работу! Загрузим пакет `boo` ("бухгалтерская отчетность организаций")  с github. Проследим также за установкой необходимых зависимостей.

# %%
# !pip install --upgrade git+https://github.com/ru-corporate/sandbox.git@master
# Out:
# Collecting git+https://github.com/ru-corporate/sandbox.git@master
#   Cloning https://github.com/ru-corporate/sandbox.git (to revision master) to /tmp/pip-req-build-knjau5wg
# Requirement already satisfied, skipping upgrade: requests in /usr/local/lib/python3.6/dist-packages (from boo==0.0.2) (2.18.4)
# Requirement already satisfied, skipping upgrade: pandas in /usr/local/lib/python3.6/dist-packages (from boo==0.0.2) (0.22.0)
# Requirement already satisfied, skipping upgrade: tqdm in /usr/local/lib/python3.6/dist-packages (from boo==0.0.2) (4.28.1)
# Requirement already satisfied, skipping upgrade: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->boo==0.0.2) (2.6)
# Requirement already satisfied, skipping upgrade: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->boo==0.0.2) (1.22)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->boo==0.0.2) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->boo==0.0.2) (2018.11.29)
# Requirement already satisfied, skipping upgrade: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas->boo==0.0.2) (2018.9)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from pandas->boo==0.0.2) (1.14.6)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2 in /usr/local/lib/python3.6/dist-packages (from pandas->boo==0.0.2) (2.5.3)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2->pandas->boo==0.0.2) (1.11.0)
# Building wheels for collected packages: boo
#   Building wheel for boo (setup.py) ... done
#   Stored in directory: /tmp/pip-ephem-wheel-cache-vkvij7zp/wheels/d4/6e/d4/eeca7bd25b87c086542888db1c747824a70ba3ec67b0d3823d
# Successfully built boo
# Installing collected packages: boo
# Successfully installed boo-0.0.2

# %% [markdown]
# Пакет `boo` позволяет загрузить и "причесать" данные для более быстрого и удобного использования. Загрузка данных и поготовка данных может занимать длительное время, но на Google Colab все поисходит довольно шустро, а сами файлы некоторое время (кто-то написано сколько?) хранятся на локальной машине и готовы для использования.

# %%
import boo

# %%
boo.download(2012)
boo.build(2012)

# uncomment when ready to work with larger file
#boo.download(2017)
#boo.build(2017)
# Out:
# Year: 2012
# Downloading http://www.gks.ru/opendata/storage/7708234640-bdboo2012/data-20181029t000000-structure-20121231t000000.csv
# 525447 k [00:47, 11005.59 k/s]
# 859 lines [00:00, 8588.96 lines/s]
# Saved as /root/.boo/rosstat-2012.csv
# Year: 2012
# Reading and processing CSV file /root/.boo/rosstat-2012.csv
# 765813 lines [01:22, 9320.70 lines/s]
# Saved processed CSV file as /root/.boo/processed-2012.csv
# '/root/.boo/processed-2012.csv'

# %% [markdown]
# Посмотрим, где эти файлы на локальном диске. Каталог хранения данных будет отличаться на  Windows и Linux машинах.

# %%
boo.raw_filepath(2012)
# Out:
# '/root/.boo/rosstat-2012.csv'

# %%
boo.processed_filepath(2012)
# Out:
# '/root/.boo/processed-2012.csv'

# %% [markdown]
# Посмотрим на содержание каталога `/root/.boo/`. Объем обработанного файла почти в два раза меньше за счет удаления пустых и неиспользуемых столбцов.  Все строки файла переведены в тыс. рублей.

# %%
! ls -1 -sA --block-size=M ~/.boo/
# Out:
# total 724M
# 211M processed-2012.csv
# 514M rosstat-2012.csv

# %% [markdown]
# Загрузим датафрейм c помощью функции [boo.read_dataframe()](https://github.com/ru-corporate/sandbox/blob/44da3817f0432c57aa46e017849db6fc1488e187/boo/boo.py#L74-L88). Фактически мы выполняем `pd.read_csv()` с именем файла `boo.processed_filepath(2012)`  и типом столбцов, таким как `dtype={'inn':str}`. `dtype` ускоряет импорт данных и гарантирует сохранность некоторых типов (например, ИНН остается текстовой строкой,  так как он может начинаться с нуля).
#
# Чтение фрейма занимает 5-10 секунд.

# %%
_df = boo.read_dataframe(2012)
# Out:
# Year: 2012
# Reading processed CSV file /root/.boo/processed-2012.csv

# %% [markdown]
# Какие колонки у этого набора данных? И что они означают?

# %%
_df.columns
# Out:
# Index(['ok1', 'ok2', 'ok3', 'org', 'title', 'region', 'inn', 'okpo', 'okopf',
#        'okfs', 'of', 'of_lag', 'ta_fix', 'ta_fix_lag', 'cash', 'cash_lag',
#        'ta_nonfix', 'ta_nonfix_lag', 'ta', 'ta_lag', 'tp_capital',
#        'tp_capital_lag', 'debt_long', 'debt_long_lag', 'tp_long',
#        'tp_long_lag', 'debt_short', 'debt_short_lag', 'tp_short',
#        'tp_short_lag', 'tp', 'tp_lag', 'sales', 'sales_lag', 'profit_oper',
#        'profit_oper_lag', 'exp_interest', 'exp_interest_lag',
#        'profit_before_tax', 'profit_before_tax_lag', 'profit_after_tax',
#        'profit_after_tax_lag', 'cf_oper_in', 'cf_oper_in_sales', 'cf_oper_out',
#        'paid_to_supplier', 'paid_to_worker', 'paid_interest',
#        'paid_profit_tax', 'paid_other_costs', 'cf_oper', 'cf_inv_in',
#        'cf_inv_out', 'paid_fa_investment', 'cf_inv', 'cf_fin_in', 'cf_fin_out',
#        'cf_fin', 'cf'],
#       dtype='object')

# %%
import pandas as pd
_c = pd.DataFrame(index=_df.columns)
_c['Описание'] = _c.index.map(boo.whatis)
_c
# FIXME: boo.whatis не обьясняет что такое _lag - значение переменной 
#        на начало периода
# Out:
#                                                                 Описание
# ok1                                             Код ОКВЭД первого уровня
# ok2                                             Код ОКВЭД второго уровня
# ok3                                            Код ОКВЭД третьего уровня
# org                    Тип юридического лица (часть наименования орга...
# title                                      Короткое название организации
# region                                                Код региона по ИНН
# inn                                                                  ИНН
# okpo                                                                ОКПО
# okopf                                                              ОКОПФ
# okfs                                                                ОКФС
# of                                                     Основные средства
# of_lag                                                 Основные средства
# ta_fix                                        Итого внеоборотных активов
# ta_fix_lag                                    Итого внеоборотных активов
# cash                            Денежные средства и денежные эквиваленты
# cash_lag                        Денежные средства и денежные эквиваленты
# ta_nonfix                                        Итого оборотных активов
# ta_nonfix_lag                                    Итого оборотных активов
# ta                                                        БАЛАНС (актив)
# ta_lag                                                    БАЛАНС (актив)
# tp_capital                                                 Итого капитал
# tp_capital_lag                                             Итого капитал
# debt_long                                  Долгосрочные заемные средства
# debt_long_lag                              Долгосрочные заемные средства
# tp_long                                  Итого долгосрочных обязательств
# tp_long_lag                              Итого долгосрочных обязательств
# debt_short                           Краткосрочные заемные обязательства
# debt_short_lag                       Краткосрочные заемные обязательства
# tp_short                                Итого краткосрочных обязательств
# tp_short_lag                            Итого краткосрочных обязательств
# tp                                                       БАЛАНС (пассив)
# tp_lag                                                   БАЛАНС (пассив)
# sales                                                            Выручка
# sales_lag                                                        Выручка
# profit_oper                                   Прибыль (убыток) от продаж
# profit_oper_lag                               Прибыль (убыток) от продаж
# exp_interest                                           Проценты к уплате
# exp_interest_lag                                       Проценты к уплате
# profit_before_tax                    Прибыль (убыток) до налогообложения
# profit_before_tax_lag                Прибыль (убыток) до налогообложения
# profit_after_tax                                 Чистая прибыль (убыток)
# profit_after_tax_lag                             Чистая прибыль (убыток)
# cf_oper_in                                           Поступления - всего
# cf_oper_in_sales            От продажи продукции, товаров, работ и услуг
# cf_oper_out                                              Платежи - всего
# paid_to_supplier       Поставщикам (подрядчикам) за сырье, материалы,...
# paid_to_worker                        В связи с оплатой труда работников
# paid_interest                        Проценты по долговым обязательствам
# paid_profit_tax                            Налога на прибыль организаций
# paid_other_costs                                          Прочие платежи
# cf_oper                      Сальдо денежных потоков от текущих операций
# cf_inv_in                                            Поступления - всего
# cf_inv_out                                               Платежи - всего
# paid_fa_investment     В связи с приобретением, созданием, модернизац...
# cf_inv                 Сальдо денежных потоков от инвестиционных опер...
# cf_fin_in                                            Поступления - всего
# cf_fin_out                                               Платежи - всего
# cf_fin                    Сальдо денежных потоков от финансовых операций
# cf                            Сальдо денежных потоков за отчетный период

# %% [markdown]
# ### Задания
#
# Прочитайте еще раз [названия переменных в README](https://github.com/ru-corporate/sandbox/tree/44da3817f0432c57aa46e017849db6fc1488e187#%D0%BE%D0%B1%D0%B7%D0%BD%D0%B0%D1%87%D0%B5%D0%BD%D0%B8%D1%8F-%D0%BF%D0%B5%D1%80%D0%B5%D0%BC%D0%B5%D0%BD%D0%BD%D1%8B%D1%85). Найдите в интернете бухгалтерский отчет какого-нибудь предприятия.
#
# 1. Какие части отчтености представляют эти переменные? Как проверить правильность составления баланса? Составьте код для такой проверки.
# 2. Получите ключевые значения отчетности выбранного предприятия из базы данных. Сравните с данными с сайта. Опишите результат.

# %% [markdown]
# ## Сделаем набор данных удобным
#
#  | Цели раздела |
#  |------------------------|
#  | 6.  Преобразовать данные отчетности  для анализа крупнейших компаний реального сектора |

# %% [markdown]
# Сначала посмотрим на крупные предприятия - по ним проще найди проверочную информацию и легче понять, есть ли ошибки в отчтености. Наша основная задача сейчас - найти крупные предприятия и сделать отченость более понятной и удобной для работы.
#
# Ограничимся небольшим числом переменных - объем активов, основные средства, продажи, прибыль, денежный поток.

# %%
BLN =  10 ** 6
COLUMN_REG = ['region', 'ok1', 'ok2', 'ok3', 'title']
COLUMN_RUB = ['ta', 'of', 'sales', 'profit_before_tax', 'cf']
df = _df[(_df.cf != 0) & (_df.ta > 0)] \
         .set_index("inn") \
         [COLUMN_REG+COLUMN_RUB]

df.loc[:, COLUMN_RUB] = df.loc[:, COLUMN_RUB].divide(other=BLN).round(1)


def dequote(title):
    return boo.row.dequote(str(title))[1] \
           .replace("ПУБЛИЧНОЕ АКЦИОНЕРНОЕ ОБЩЕСТВО", "ПАО") \
           .replace("ОТКРЫТОЕ АКЦИОНЕРНОЕ ОБЩЕСТВО", "ОАО") \
           .replace("НЕФТЕПЕРЕРАБАТЫВАЮЩИЙ ЗАВОД", "НПЗ")\
           .replace("ГЕНЕРИРУЮЩАЯ КОМПАНИЯ ОПТОВОГО РЫНКА ЭЛЕКТРОЭНЕРГИИ", "ОГК")
  

df.loc[:, 'title'] = df.loc[:, 'title'].apply(dequote)

SHORT_NAMES_BY_INN = {
    '2460066195': "РусГидро",
    '4716016979': "ФСК ЕЭС",
    '7702038150': "Московский метрополитен",
    '7721632827': "Концерн Росэнергоатом",
    '7706664260': "Атомэнергопром"
}

def rename(df, rename_dict=SHORT_NAMES_BY_INN):
    """Rename some titles."""
    ix = df.index.isin(list(rename_dict.keys()))
    df.loc[ix, ['title']] = df.loc[ix].index.map(lambda inn: rename_dict[inn])
    return df
  
df = rename(df)
# важное, существенное ограничение
df = df[df.of>0.01]

print("Количество компаний (исходное):      ", _df.shape[0])
print("Количество компаний (после фильтров):", df.shape[0])
df.head(10)


def sort(df, key):
    return df.sort_values(key, ascending=False)
  
def by_title(df, text):
    mask = df.title.map(lambda s: text.lower() in str(s).lower())
    return df[mask]
# Out:
# Количество компаний (исходное):       765813
# Количество компаний (после фильтров): 21096

# %%
# пример укроченного названия
inn1 = "2607018122"
print(_df[_df.inn == inn1].title)
df.loc[inn1, :].title
# Out:
# 95803    ВТОРАЯ ГЕНЕРИРУЮЩАЯ КОМПАНИЯ ОПТОВОГО РЫНКА ЭЛ...
# Name: title, dtype: object
# 'ВТОРАЯ ОГК'

# %% [markdown]
# #### TODO: что не сделано
#
# - пояснить смысл ограничения `(_df.cf != 0)`
# - показать способ реклассификации отраслей
# - сократить список меньше 0.01 млрд активов или продаж
# - разбить преобразования на группы, возможно перегруппировать
# - выбор отрасли в меню

# %% [markdown]
# ### Далее пробуем выборки крупных компаний

# %%
sort(df, "sales").head(50)
# Out:
#            region  ok1  ok2  ok3                                     title  \
# inn
# 7736050003     77   51   51    3                                   Газпром
# 7706107510     77   23   20    0                                  Роснефть
# 7708503727     77   60   10    1                Российские железные дороги
# 7225004092     72   51   51    0                            ТНК-ВР Холдинг
# 5504036333     55   51   51    0                             Газпром нефть
# 5003021311     50   51   51    3                      Газпром межрегионгаз
# 8602060555     86   11   10   11                            СУРГУТНЕФТЕГАЗ
# 7706061801     77   60   30    1                                Транснефть
# 8608048498     86   11   10   11                    ЛУКОЙЛ-Западная Сибирь
# 0274051582     02   23   20    0                                  Башнефть
# 2310031475     23   52   12    0                                    ТАНДЕР
# 7728029110     77   52   11    0                               ПЕРЕКРЕСТОК
# 5003052454     50   51   17    0                                 МЕГАПОЛИС
# 1644003838     16   11   10   11                                  Татнефть
# 5250043567     52   23   20    0            ЛУКОЙЛ-НИЖЕГОРОДНЕФТЕОРГСИНТЕЗ
# 7729588440     77   45   21    0                            СТРОЙГАЗМОНТАЖ
# 8401005730     84   27   45    0                         НОРИЛЬСКИЙ НИКЕЛЬ
# 7707049388     77   64   20   11                                Ростелеком
# 7713076301     77   64   20    1                       Вымпел-Коммуникации
# 1106014140     11   11   10   11                               ЛУКОЙЛ-Коми
# 7740000076     77   64   20   11                     Мобильные ТелеСистемы
# 5042059767     50   34    1    0                      ФОЛЬКСВАГЕН Груп Рус
# 5905099475     59   23   20    0                 ЛУКОЙЛ-Пермнефтеоргсинтез
# 8622000931     86   60   30   21                   Газпром трансгаз Югорск
# 7812014560     78   64   20    0                                   МегаФон
# 3448017919     34   23   20    0          ЛУКОЙЛ-Волгограднефтепереработка
# 7727547261     77   23   20    0                             СИБУР Холдинг
# 7414003633     74   27   10   64  Магнитогорский металлургический комбинат
# 4823006703     48   27   10    7    Новолипецкий металлургический комбинат
# 7703270067     77   52   11    0                                      АШАН
# 7710390358     77   50   10    1                              ТОЙОТА МОТОР
# 3528000597     35   27    0    0                                СЕВЕРСТАЛЬ
# 5612002469     56   11   10   11                             Оренбургнефть
# 8603089934     86   11   10   11                          Самотлорнефтегаз
# 2437261631     24   11   10   11                               ВАНКОРНЕФТЬ
# 7736520080     77   40   13    2                             Мосэнергосбыт
# 8904034777     89   11   10    2                     Газпром добыча Ямбург
# 7721632827     77   40   11    3                     Концерн Росэнергоатом
# 7704218694     77   51   38    0                       МЕТРО Кэш энд Керри
# 6320002223     63   34   10    2                                   АВТОВАЗ
# 7708709686     77   60   10   11         Федеральная пассажирская компания
# 5902201970     59   11   10   11                              ЛУКОЙЛ-ПЕРМЬ
# 7709258228     77   67   12    1                          Ренессанс Брокер
# 7712040126     77   62   10    0             АЭРОФЛОТ-РОССИЙСКИЕ АВИАЛИНИИ
# 8604035473     86   11   20    4                         РН-Юганскнефтегаз
# 6316031581     63   51   51    3                                   НОВАТЭК
# 7801059506     78   51   35    0         Дж. Т.И. по Маркетингу и Продажам
# 7705035012     77   40   11    1                                 Мосэнерго
# 0266008329     02   23   20    0                  Газпром нефтехим Салават
# 5009033419     50   51   51    0               Газпром межрегионгаз Москва
#
#                  ta      of   sales  profit_before_tax     cf
# inn
# 7736050003  10035.7  5569.6  3659.2              753.7  -60.7
# 7706107510   2492.0   715.8  2595.7              345.6  135.8
# 7708503727   4330.8  3413.7  1366.0               66.2  -67.2
# 7225004092    693.5     6.1  1084.4              200.7   32.3
# 5504036333    754.7    14.7   905.5               96.9   46.6
# 5003021311    601.2    39.1   828.0               -9.7    6.1
# 8602060555   1797.1   564.0   815.6              195.0   21.0
# 7706061801    908.8     4.1   687.1               17.1  -55.4
# 8608048498    508.6   352.5   645.7              140.6    0.0
# 0274051582    339.6   100.3   489.2               57.2   -6.3
# 2310031475    210.3   106.3   477.5               24.5   -4.6
# 7728029110    137.1    23.7   419.8                2.5    0.9
# 5003052454    114.4     0.1   381.8               10.9    2.7
# 1644003838    474.6    94.8   344.6               86.9   -7.7
# 5250043567    128.3    33.9   326.2               29.9    0.0
# 7729588440    160.7     0.9   324.7               37.4    0.4
# 8401005730    703.0   116.5   288.6               99.3    8.1
# 7707049388    563.2   331.3   282.9               41.2    3.8
# 7713076301    514.9   143.2   280.3               46.6    8.0
# 1106014140    223.4   145.5   279.9               44.5   -0.0
# 7740000076    447.9   141.4   270.8               56.3  -34.4
# 5042059767    108.0    26.9   258.8               12.8    3.5
# 5905099475    158.4    18.1   256.7               38.0    0.0
# 8622000931    126.4    72.9   255.9                3.3   -0.6
# 7812014560    384.1   185.1   254.5               54.9   -0.8
# 3448017919    131.7    34.2   248.7               34.5   -0.0
# 7727547261    314.8     0.1   243.3               65.2   -1.5
# 7414003633    328.6   151.5   243.1               11.4    0.1
# 4823006703    471.2   153.5   240.1               29.0    8.6
# 7703270067     72.7    28.8   232.6               12.9   -0.5
# 7710390358     37.0     2.9   227.7               15.9   -1.1
# 3528000597    423.3    78.7   223.6               16.3    3.5
# 5612002469    231.2   116.5   218.5               79.3    0.0
# 8603089934    140.6    78.1   217.4               34.9   -0.1
# 2437261631    417.5   345.1   215.8               43.4   -0.7
# 7736520080     31.1     5.2   213.5                1.9   -8.6
# 8904034777    116.5    54.4   205.7                2.9    0.1
# 7721632827   1087.8   933.6   200.5                3.2   -3.7
# 7704218694     91.3    43.2   186.2               17.2    5.9
# 6320002223    144.1    65.4   183.2                0.5    1.0
# 7708709686    206.1   167.0   183.0                5.9    8.4
# 5902201970    176.7    80.2   180.5               52.4    0.0
# 7709258228     14.8     0.1   179.2                0.6   -2.6
# 7712040126    107.6    13.9   177.9                8.4    9.8
# 8604035473     65.4    16.7   171.0                2.4    0.0
# 6316031581    319.8     0.3   169.9               61.2   -3.8
# 7801059506     34.9     0.6   165.8               23.2   -0.8
# 7705035012    227.6   146.9   155.4               10.8  -13.2
# 0266008329    111.5    54.8   153.6                0.5    8.6
# 5009033419     27.7     0.2   152.3                0.3    0.4

# %%
sort(df, "ta").head(50)
# Out:
#            region  ok1  ok2  ok3  \
# inn
# 7736050003     77   51   51    3
# 7708503727     77   60   10    1
# 7706107510     77   23   20    0
# 8602060555     86   11   10   11
# 7708004767     77   74   15    2
# 7702038150     77   60   21   23
# 7706664260     77   72    6    0
# 4716016979     47   40   12    0
# 7721632827     77   40   11    3
# 7706061801     77   60   30    1
# 7706413348     77   75   11    0
# 5504036333     55   51   51    0
# 2460066195     24   40   11    2
# 8401005730     84   27   45    0
# 7225004092     72   51   51    0
# 7703104630     77   65   23    1
# 5003021311     50   51   51    3
# 7707049388     77   64   20   11
# 7713076301     77   64   20    1
# 8608048498     86   11   10   11
# 3801079671     38   60   30   11
# 1644003838     16   11   10   11
# 4823006703     48   27   10    7
# 7740000076     77   64   20   11
# 2320109650     23   40   11    1
# 7728149400     77   45   21    3
# 3528000597     35   27    0    0
# 2437261631     24   11   10   11
# 2724132118     27   60   30   11
# 7812014560     78   64   20    0
# 7704274402     77   65   23    0
# 7718852163     77   51   19    0
# 0274051582     02   23   20    0
# 7414003633     74   27   10   64
# 6316031581     63   51   51    3
# 7727547261     77   23   20    0
# 5036065113     50   40   12    0
# 7838306818     78   40   20    2
# 7709413138     77   65   21    0
# 6623000680     66   27   11    0
# 8903019871     89   11   10    2
# 7708619320     77   73   10    0
# 7736003162     77   70   11    1
# 5612002469     56   11   10   11
# 7704784450     77   40   11    0
# 7705035012     77   40   11    1
# 1106014140     11   11   10   11
# 7709378229     77   65   21    0
# 7720518494     77   40   30    1
# 3235002178     32   60   30   11
#
#                                                       title       ta      of  \
# inn
# 7736050003                                          Газпром  10035.7  5569.6
# 7708503727                       Российские железные дороги   4330.8  3413.7
# 7706107510                                         Роснефть   2492.0   715.8
# 8602060555                                   СУРГУТНЕФТЕГАЗ   1797.1   564.0
# 7708004767                                           ЛУКОЙЛ   1188.8     7.5
# 7702038150                          Московский метрополитен   1139.9   973.5
# 7706664260                                   Атомэнергопром   1136.4     0.4
# 4716016979                                          ФСК ЕЭС   1123.0    52.8
# 7721632827                            Концерн Росэнергоатом   1087.8   933.6
# 7706061801                                       Транснефть    908.8     4.1
# 7706413348                                          Росатом    901.8     1.8
# 5504036333                                    Газпром нефть    754.7    14.7
# 2460066195                                         РусГидро    753.8   331.9
# 8401005730                                НОРИЛЬСКИЙ НИКЕЛЬ    703.0   116.5
# 7225004092                                   ТНК-ВР Холдинг    693.5     6.1
# 7703104630                                          СИСТЕМА    602.9     2.4
# 5003021311                             Газпром межрегионгаз    601.2    39.1
# 7707049388                                       Ростелеком    563.2   331.3
# 7713076301                              Вымпел-Коммуникации    514.9   143.2
# 8608048498                           ЛУКОЙЛ-Западная Сибирь    508.6   352.5
# 3801079671    Восточно-Сибирские магистральные нефтепроводы    496.8   368.9
# 1644003838                                         Татнефть    474.6    94.8
# 4823006703           Новолипецкий металлургический комбинат    471.2   153.5
# 7740000076                            Мобильные ТелеСистемы    447.9   141.4
# 2320109650                                    ИНТЕР РАО ЕЭС    444.7     3.2
# 7728149400                                    ЯМАЛГАЗИНВЕСТ    439.5   220.4
# 3528000597                                       СЕВЕРСТАЛЬ    423.3    78.7
# 2437261631                                      ВАНКОРНЕФТЬ    417.5   345.1
# 2724132118                      ТРАНСНЕФТЬ - ДАЛЬНИЙ ВОСТОК    384.2   208.0
# 7812014560                                          МегаФон    384.1   185.1
# 7704274402                                    Ростехнологии    369.3     8.0
# 7718852163                                 Рособоронэкспорт    345.5     2.9
# 0274051582                                         Башнефть    339.6   100.3
# 7414003633         Магнитогорский металлургический комбинат    328.6   151.5
# 6316031581                                          НОВАТЭК    319.8     0.3
# 7727547261                                    СИБУР Холдинг    314.8     0.1
# 5036065113  Московская объединенная электросетевая компания    286.7   216.7
# 7838306818                        Газпром газораспределение    271.0   124.7
# 7709413138                                       ВЭБ-лизинг    270.2     0.2
# 6623000680  ЕВРАЗ Нижнетагильский металлургический комбинат    265.6    38.1
# 8903019871                             Газпром добыча Надым    263.8   156.7
# 7708619320         Объединенная авиастроительная корпорация    258.5     0.1
# 7736003162                     Строительное управление №155    255.5    14.8
# 5612002469                                    Оренбургнефть    231.2   116.5
# 7704784450                     ИНТЕР РАО - Электрогенерация    229.2   170.3
# 7705035012                                        Мосэнерго    227.6   146.9
# 1106014140                                      ЛУКОЙЛ-Коми    223.4   145.5
# 7709378229       ВТБ Лизинг (открытое акционерное общество)    221.8     0.2
# 7720518494  Московская объединенная энергетическая компания    211.6   127.3
# 3235002178                              ТРАНСНЕФТЬ - ДРУЖБА    210.7   140.8
#
#              sales  profit_before_tax     cf
# inn
# 7736050003  3659.2              753.7  -60.7
# 7708503727  1366.0               66.2  -67.2
# 7706107510  2595.7              345.6  135.8
# 8602060555   815.6              195.0   21.0
# 7708004767    39.9              218.7  -11.1
# 7702038150    68.4                7.9   32.3
# 7706664260     1.3               21.4   -8.5
# 4716016979   138.8              -14.2    0.3
# 7721632827   200.5                3.2   -3.7
# 7706061801   687.1               17.1  -55.4
# 7706413348     0.1               10.5    9.1
# 5504036333   905.5               96.9   46.6
# 2460066195    94.2               22.8   -6.8
# 8401005730   288.6               99.3    8.1
# 7225004092  1084.4              200.7   32.3
# 7703104630    26.5               86.3  -11.0
# 5003021311   828.0               -9.7    6.1
# 7707049388   282.9               41.2    3.8
# 7713076301   280.3               46.6    8.0
# 8608048498   645.7              140.6    0.0
# 3801079671    84.9               21.0   -0.5
# 1644003838   344.6               86.9   -7.7
# 4823006703   240.1               29.0    8.6
# 7740000076   270.8               56.3  -34.4
# 2320109650    42.7               -9.8    9.4
# 7728149400    23.4                0.2   -0.7
# 3528000597   223.6               16.3    3.5
# 2437261631   215.8               43.4   -0.7
# 2724132118     2.9                4.2    0.3
# 7812014560   254.5               54.9   -0.8
# 7704274402     0.6               10.1   -5.7
# 7718852163    17.3                8.3   47.7
# 0274051582   489.2               57.2   -6.3
# 7414003633   243.1               11.4    0.1
# 6316031581   169.9               61.2   -3.8
# 7727547261   243.3               65.2   -1.5
# 5036065113   118.0               20.9    4.5
# 7838306818    11.5                0.7    0.3
# 7709413138    42.1                3.6  -13.3
# 6623000680   113.0               28.1   15.5
# 8903019871    79.9                0.9   -0.7
# 7708619320    12.0               -0.1    1.0
# 7736003162    53.7                1.1    1.1
# 5612002469   218.5               79.3    0.0
# 7704784450    45.6               -0.3   -6.0
# 7705035012   155.4               10.8  -13.2
# 1106014140   279.9               44.5   -0.0
# 7709378229    28.8                2.2   -0.3
# 7720518494    85.8               -2.4   -5.6
# 3235002178    63.4               32.6   -0.0

# %%
sort(df, "profit_before_tax").head(200)
# Out:
#            region  ok1  ok2  ok3  \
# inn
# 7736050003     77   51   51    3
# 7706107510     77   23   20    0
# 7708004767     77   74   15    2
# 7225004092     72   51   51    0
# 8602060555     86   11   10   11
# 8608048498     86   11   10   11
# 8401005730     84   27   45    0
# 5504036333     55   51   51    0
# 1644003838     16   11   10   11
# 7703104630     77   65   23    1
# 5612002469     56   11   10   11
# 7708503727     77   60   10    1
# 7727547261     77   23   20    0
# 3808079367     38   11   10   11
# 6316031581     63   51   51    3
# 5911029807     59   24   15    0
# 0274051582     02   23   20    0
# 7740000076     77   64   20   11
# 7812014560     78   64   20    0
# 5902201970     59   11   10   11
# 5260900725     52   60   30   11
# 7713076301     77   64   20    1
# 7708643971     77   63    4    0
# 1106014140     11   11   10   11
# 2437261631     24   11   10   11
# 7707049388     77   64   20   11
# 6315229162     63   11   10   11
# 5905099475     59   23   20    0
# 7729588440     77   45   21    0
# 7201000726     72   60   30   11
# ...           ...  ...  ...  ...
# 7708709686     77   60   10   11
# 7703191457     77   92   20    0
# 7705705370     77   60   10   11
# 7802084569     78   45   21    1
# 7726311464     77   51   90    0
# 6325004584     63   23   20    0
# 5075018950     50   29   71    0
# 7705503750     77   63   40    0
# 5905021239     59   24   15    0
# 6617001534     66   13   20   41
# 7451047011     74   27   22   63
# 6704000505     67   24   15    0
# 7725216105     77   51   46    0
# 1655049111     16   40   10    0
# 7726059896     77   51   45    0
# 4214000252     42   10   10   11
# 8603089941     86   11   10   11
# 8620012762     86   11   10   11
# 2508081814     25   63   11    2
# 2715005530     27   13   20   41
# 1645000340     16   60   30   11
# 2607018122     26   40   11    1
# 5406192366     54   10   10   11
# 4212024138     42   10   10   12
# 5610058025     56   11   10   21
# 2443000518     24   23   20    0
# 6340007043     63   25   23    0
# 2426003607     24   13   20    5
# 7706199246     77   70   31   12
# 7734135124     77   63   23    2
#
#                                                         title       ta  \
# inn
# 7736050003                                            Газпром  10035.7
# 7706107510                                           Роснефть   2492.0
# 7708004767                                             ЛУКОЙЛ   1188.8
# 7225004092                                     ТНК-ВР Холдинг    693.5
# 8602060555                                     СУРГУТНЕФТЕГАЗ   1797.1
# 8608048498                             ЛУКОЙЛ-Западная Сибирь    508.6
# 8401005730                                  НОРИЛЬСКИЙ НИКЕЛЬ    703.0
# 5504036333                                      Газпром нефть    754.7
# 1644003838                                           Татнефть    474.6
# 7703104630                                            СИСТЕМА    602.9
# 5612002469                                      Оренбургнефть    231.2
# 7708503727                         Российские железные дороги   4330.8
# 7727547261                                      СИБУР Холдинг    314.8
# 3808079367                                Верхнечонскнефтегаз    105.4
# 6316031581                                            НОВАТЭК    319.8
# 5911029807                                          Уралкалий    197.7
# 0274051582                                           Башнефть    339.6
# 7740000076                              Мобильные ТелеСистемы    447.9
# 7812014560                                            МегаФон    384.1
# 5902201970                                       ЛУКОЙЛ-ПЕРМЬ    176.7
# 5260900725                          ТРАНСНЕФТЬ -ВЕРХНЯЯ ВОЛГА    102.4
# 7713076301                                Вымпел-Коммуникации    514.9
# 7708643971                           Первая грузовая компания    137.6
# 1106014140                                        ЛУКОЙЛ-Коми    223.4
# 2437261631                                        ВАНКОРНЕФТЬ    417.5
# 7707049388                                         Ростелеком    563.2
# 6315229162                                     Самаранефтегаз     97.9
# 5905099475                          ЛУКОЙЛ-Пермнефтеоргсинтез    158.4
# 7729588440                                     СТРОЙГАЗМОНТАЖ    160.7
# 7201000726                                     Сибнефтепровод    208.6
# ...                                                       ...      ...
# 7708709686                  Федеральная пассажирская компания    206.1
# 7703191457                                   Телекомпания НТВ     29.5
# 7705705370      Центральная пригородная пассажирская компания      9.7
# 7802084569                                         ЛенСпецСМУ     54.1
# 7726311464                                             Р-Фарм     28.8
# 6325004584             Сызранский нефтеперерабатывающий завод     24.1
# 5075018950                                 ЛГ Электроникс РУС     30.4
# 7705503750                        Новая перевозочная компания     36.4
# 5905021239                              Минеральные удобрения      9.2
# 6617001534                             Золото Северного Урала     17.2
# 7451047011                                        Трубодеталь     19.1
# 6704000505                                          Дорогобуж     29.7
# 7725216105                                  Джонсон & Джонсон     22.7
# 1655049111                                   Сетевая компания     36.4
# 7726059896                                           Л`Ореаль     10.3
# 4214000252                                         МЕЖДУРЕЧЬЕ     16.2
# 8603089941    Нижневартовское нефтегазодобывающее предприятие     25.8
# 8620012762                            Славнефть-Нижневартовск     20.4
# 2508081814                         ТРАНСНЕФТЬ - ПОРТ КОЗЬМИНО     77.1
# 2715005530              ОХОТСКАЯ ГОРНО-ГЕОЛОГИЧЕСКАЯ КОМПАНИЯ     14.0
# 1645000340         Северо-западные магистральные нефтепроводы     76.5
# 2607018122                                         ВТОРАЯ ОГК    136.7
# 5406192366                                 Сибирский Антрацит     12.7
# 4212024138                                       СУЭК-Кузбасс     45.0
# 5610058025                            Газпром добыча Оренбург     49.8
# 2443000518           АЧИНСКИЙ НПЗ ВОСТОЧНОЙ НЕФТЯНОЙ КОМПАНИИ     32.5
# 6340007043                                            ТАРКЕТТ     12.4
# 2426003607              НОВОАНГАРСКИЙ ОБОГАТИТЕЛЬНЫЙ КОМБИНАТ     11.2
# 7706199246                           Каширский двор-Северянин     24.1
# 7734135124  Государственная корпорация по организации возд...     58.1
#
#                 of   sales  profit_before_tax     cf
# inn
# 7736050003  5569.6  3659.2              753.7  -60.7
# 7706107510   715.8  2595.7              345.6  135.8
# 7708004767     7.5    39.9              218.7  -11.1
# 7225004092     6.1  1084.4              200.7   32.3
# 8602060555   564.0   815.6              195.0   21.0
# 8608048498   352.5   645.7              140.6    0.0
# 8401005730   116.5   288.6               99.3    8.1
# 5504036333    14.7   905.5               96.9   46.6
# 1644003838    94.8   344.6               86.9   -7.7
# 7703104630     2.4    26.5               86.3  -11.0
# 5612002469   116.5   218.5               79.3    0.0
# 7708503727  3413.7  1366.0               66.2  -67.2
# 7727547261     0.1   243.3               65.2   -1.5
# 3808079367    76.0    77.7               63.7   -0.0
# 6316031581     0.3   169.9               61.2   -3.8
# 5911029807    70.9   110.1               58.4   22.3
# 0274051582   100.3   489.2               57.2   -6.3
# 7740000076   141.4   270.8               56.3  -34.4
# 7812014560   185.1   254.5               54.9   -0.8
# 5902201970    80.2   180.5               52.4    0.0
# 5260900725    49.6    65.8               51.5   -0.0
# 7713076301   143.2   280.3               46.6    8.0
# 7708643971    90.2   119.5               46.1   -5.1
# 1106014140   145.5   279.9               44.5   -0.0
# 2437261631   345.1   215.8               43.4   -0.7
# 7707049388   331.3   282.9               41.2    3.8
# 6315229162    30.9   113.4               39.5   -0.0
# 5905099475    18.1   256.7               38.0    0.0
# 7729588440     0.9   324.7               37.4    0.4
# 7201000726   146.1    84.5               35.8   -0.0
# ...            ...     ...                ...    ...
# 7708709686   167.0   183.0                5.9    8.4
# 7703191457     0.8    22.1                5.8   -0.8
# 7705705370     0.9    27.3                5.8    2.5
# 7802084569     5.8    14.8                5.8    5.8
# 7726311464     2.1    41.9                5.6   -4.0
# 6325004584    18.4    13.3                5.5   -0.0
# 5075018950     5.1    79.5                5.5    0.6
# 7705503750    26.1    21.9                5.5    0.1
# 5905021239     2.5    11.3                5.5    0.0
# 6617001534     1.7     8.5                5.4    0.0
# 7451047011     3.8    11.3                5.4   -0.0
# 6704000505     3.6    15.1                5.4   -1.1
# 7725216105     0.6    43.9                5.4    1.9
# 1655049111    25.8    19.2                5.3   -1.5
# 7726059896     2.4    32.2                5.3   -0.1
# 4214000252     2.0    11.3                5.3    0.7
# 8603089941    16.1    35.4                5.3   -0.0
# 8620012762    17.5    19.3                5.2   -0.0
# 2508081814    50.3     9.5                5.2   -0.0
# 2715005530     2.4     9.8                5.1   -0.1
# 1645000340    63.8    26.9                5.1    0.0
# 2607018122    82.0   104.1                5.1    3.4
# 5406192366     7.4    15.0                5.1    1.7
# 4212024138    33.8    53.0                5.1   -0.4
# 5610058025    24.4    56.6                5.1   -0.5
# 2443000518    26.3    11.3                5.1   -0.0
# 6340007043     3.7    15.8                5.1    0.1
# 2426003607     2.0    10.1                5.0   -0.5
# 7706199246    19.2     5.4                4.9    0.1
# 7734135124    22.9    48.2                4.9   -0.4
#
# [200 rows x 10 columns]

# %% [markdown]
# ### Смотрим отдельные холдинги

# %%
# Мы видим только российские активы https://www.interrao.ru/company/structure/
sort(by_title(df, "ИНТЕР РАО"), "ta").head(10)
# Out:
#            region  ok1  ok2  ok3                         title     ta     of  \
# inn
# 2320109650     23   40   11    1                 ИНТЕР РАО ЕЭС  444.7    3.2
# 7704784450     77   40   11    0  ИНТЕР РАО - Электрогенерация  229.2  170.3
#
#             sales  profit_before_tax   cf
# inn
# 2320109650   42.7               -9.8  9.4
# 7704784450   45.6               -0.3 -6.0

# %%
sort(by_title(df, "ЛУКОЙЛ"), "ta").head(10)
# Out:
#            region  ok1  ok2  ok3                             title      ta  \
# inn
# 7708004767     77   74   15    2                            ЛУКОЙЛ  1188.8
# 8608048498     86   11   10   11            ЛУКОЙЛ-Западная Сибирь   508.6
# 1106014140     11   11   10   11                       ЛУКОЙЛ-Коми   223.4
# 5902201970     59   11   10   11                      ЛУКОЙЛ-ПЕРМЬ   176.7
# 5905099475     59   23   20    0         ЛУКОЙЛ-Пермнефтеоргсинтез   158.4
# 3448017919     34   23   20    0  ЛУКОЙЛ-Волгограднефтепереработка   131.7
# 5250043567     52   23   20    0    ЛУКОЙЛ-НИЖЕГОРОДНЕФТЕОРГСИНТЕЗ   128.3
# 3444070534     34   11   10   11           ЛУКОЙЛ-Нижневолжскнефть   127.7
# 1102057865     11   23   20    0       ЛУКОЙЛ-Ухтанефтепереработка    34.6
# 3900004998     39   11   10   11        ЛУКОЙЛ-Калининградморнефть    26.4
#
#                of  sales  profit_before_tax    cf
# inn
# 7708004767    7.5   39.9              218.7 -11.1
# 8608048498  352.5  645.7              140.6   0.0
# 1106014140  145.5  279.9               44.5  -0.0
# 5902201970   80.2  180.5               52.4   0.0
# 5905099475   18.1  256.7               38.0   0.0
# 3448017919   34.2  248.7               34.5  -0.0
# 5250043567   33.9  326.2               29.9   0.0
# 3444070534   58.3   19.6               -1.8  -0.0
# 1102057865    7.7   70.0                6.9  -0.0
# 3900004998    7.5   27.3                4.5  -0.0

# %%
by_title(df, "Евраз ")
# Out:
#            region  ok1  ok2  ok3  \
# inn
# 2508001449     25   63   11    2
# 4218000951     42   27   16    1
# 6154062128     61   51   52   21
# 6623000680     66   27   11    0
# 6615001962     66   13   10    2
# 6623000708     66   13   10    1
# 7105008754     71   27   13    0
#
#                                                         title     ta    of  \
# inn
# 2508001449           ЕВРАЗ НАХОДКИНСКИЙ МОРСКОЙ ТОРГОВЫЙ ПОРТ    1.7   0.9
# 4218000951  ЕВРАЗ Объединенный Западно-Сибирский металлург...   91.9  42.1
# 6154062128                                ЕВРАЗ Металл Инпром   11.4   2.4
# 6623000680    ЕВРАЗ Нижнетагильский металлургический комбинат  265.6  38.1
# 6615001962   ЕВРАЗ Качканарский горно-обогатительный комбинат   59.4   7.3
# 6623000708  ЕВРАЗ Высокогорский горно-обогатительный комбинат    9.3   1.4
# 7105008754                                 ЕВРАЗ Ванадий Тула    1.6   0.5
#
#             sales  profit_before_tax    cf
# inn
# 2508001449    2.8                0.9   0.0
# 4218000951  130.6                9.3   1.6
# 6154062128   30.1                0.1   0.2
# 6623000680  113.0               28.1  15.5
# 6615001962   28.7               10.6   3.3
# 6623000708    7.5                0.0   0.0
# 7105008754    4.4                0.2   0.0

# %%
# Газпром нефть - отдельное юрлицо "5504036333"
x = sort(by_title(df, "Газпром"), "ta")
x[x.index != "5504036333"].head(10)
# Out:
#            region  ok1  ok2  ok3                          title       ta  \
# inn
# 7736050003     77   51   51    3                        Газпром  10035.7
# 5003021311     50   51   51    3           Газпром межрегионгаз    601.2
# 7838306818     78   40   20    2      Газпром газораспределение    271.0
# 8903019871     89   11   10    2           Газпром добыча Надым    263.8
# 8905000428     89   11   10   11  Газпромнефть-Ноябрьскнефтегаз    195.6
# 7728260399     77   45    1    0              Газпром инвест Юг    168.3
# 1102054991     11   23   20    0            Газпром переработка    135.8
# 8622000931     86   60   30   21        Газпром трансгаз Югорск    126.4
# 7740000044     77   51   18    0           Газпром комплектация    124.5
# 2721152331     27   74   20   13          Газпром инвест Восток    123.0
#
#                 of   sales  profit_before_tax    cf
# inn
# 7736050003  5569.6  3659.2              753.7 -60.7
# 5003021311    39.1   828.0               -9.7   6.1
# 7838306818   124.7    11.5                0.7   0.3
# 8903019871   156.7    79.9                0.9  -0.7
# 8905000428   109.2   147.2               19.4  -0.0
# 7728260399   109.5    14.9                0.0  -6.3
# 1102054991    16.0    34.4                7.8   2.0
# 8622000931    72.9   255.9                3.3  -0.6
# 7740000044     0.7     3.0                0.6  -2.8
# 2721152331    72.0     3.8                0.2  -0.5

# %% [markdown]
# ### Смотрим отрасли

# %%
def industry(df, ok1):
    return df[df.ok1 == ok1]


def industry2(df, ok1, ok2):
    return df[(df.ok1 == ok1) & (df.ok2 == ok2)]

# %%
# TODO: add industry name from okvedv2
sort(industry(df, 64), "ta").head(10)
# Out:
#            region  ok1  ok2  ok3  \
# inn
# 7707049388     77   64   20   11
# 7713076301     77   64   20    1
# 7740000076     77   64   20   11
# 7812014560     78   64   20    0
# 7724261610     77   64   11    0
# 7710016640     77   64    2    0
# 7723011906     77   64   20    0
# 7725027605     77   64   20    0
# 7717127211     77   64   20    2
# 7717020170     77   64   20   12
#
#                                                        title     ta     of  \
# inn
# 7707049388                                        Ростелеком  563.2  331.3
# 7713076301                               Вымпел-Коммуникации  514.9  143.2
# 7740000076                             Мобильные ТелеСистемы  447.9  141.4
# 7812014560                                           МегаФон  384.1  185.1
# 7724261610                                      Почта России  208.6   21.5
# 7710016640              Московская городская телефонная сеть   74.5   36.1
# 7723011906          Cвязь объектов транспорта и добычи нефти   52.4   46.4
# 7725027605                                 Космическая связь   46.3    9.7
# 7717127211  Российская телевизионная и радиовещательная сеть   44.1    0.2
# 7717020170        Московская телекоммуникационная корпорация   30.0   10.6
#
#             sales  profit_before_tax    cf
# inn
# 7707049388  282.9               41.2   3.8
# 7713076301  280.3               46.6   8.0
# 7740000076  270.8               56.3 -34.4
# 7812014560  254.5               54.9  -0.8
# 7724261610  129.0                0.4   8.8
# 7710016640   35.0               12.7   0.9
# 7723011906   20.1                2.5   0.0
# 7725027605    6.3               10.2   5.8
# 7717127211   19.8                1.8   1.5
# 7717020170    6.6                0.1  -0.0

# %%
from boo.classify.okved import OKVEDv2

# нужен ОКВЭД-1 для 2012 года!

for i in range(0, 99):
  x = sort(industry(df, i), "ta").head(5)
  if not x.empty:
     print (i, OKVEDv2[i])
     print (x.to_string(line_width=200))
# Out:
# 1 Растениеводство и животноводство, охота и предоставление соответствующих услуг в этих областях
#            region  ok1  ok2  ok3                               title    ta    of  sales  profit_before_tax   cf
# inn
# 2328000083     23    1   30    0                        АГРОКОМПЛЕКС  30.2  13.6   15.0                1.7 -0.1
# 3123100360     31    1   24    0                          ПРИОСКОЛЬЕ  23.6  12.2   27.9                2.6 -0.2
# 3252005997     32    1   21    0            БРЯНСКАЯ МЯСНАЯ КОМПАНИЯ  22.4   3.8    0.2                1.0  0.0
# 3116003662     31    1   24    0  Белгородские гранулированные корма  20.1   8.3   13.6                2.4 -0.0
# 3110009570     31    1   23    0                Свинокомплекс Короча  17.8   4.7   23.1                0.9 -0.1
# 2 Лесоводство и лесозаготовки
#            region  ok1  ok2  ok3                            title    ta   of  sales  profit_before_tax   cf
# inn
# 2709001880     27    2    1    1                           Аркаим  19.8  6.4    5.2                0.5 -1.0
# 2460205089     24    2    1    1                    КРАСЛЕСИНВЕСТ  14.0  9.4    0.3               -1.1  0.0
# 3808119644     38    2    1    1  Транс-Сибирская лесная компания   9.6  5.3    0.2                0.1 -0.1
# 2528000813     25    2    1    1                        ТЕРНЕЙЛЕС   6.4  5.0    4.5                1.3  0.0
# 3834014616     38    2    1    1                         ЛЗД Тира   5.7  2.1    1.3               -0.0 -0.0
# 5 Добыча угля
#            region  ok1  ok2  ok3                                             title   ta   of  sales  profit_before_tax   cf
# inn
# 4101013772     41    5    1   12                                             Акрос  9.5  1.8    3.8                0.5 -0.0
# 5190405869     51    5    1   12                                     РЫБПРОМИНВЕСТ  8.9  0.4    1.7                0.8  0.1
# 2508007948     25    5    1   12  НАХОДКИНСКАЯ БАЗА АКТИВНОГО МОРСКОГО РЫБОЛОВСТВА  5.1  0.6    5.9                1.2 -0.9
# 6509006140     65    5    1   12                               Сахалин Лизинг Флот  4.8  0.6    1.4               -0.3  0.2
# 5190303200     51    5    1   12                                           КАРАТ-1  4.8  0.4    2.2                0.9 -0.0
# 10 Производство пищевых продуктов
#            region  ok1  ok2  ok3               title     ta    of  sales  profit_before_tax   cf
# inn
# 4214000608     42   10   10   21       Южный Кузбасс  102.2  17.3   31.6                4.0 -5.8
# 4205049090     42   10   10   11  Кузбассразрезуголь   86.2  45.9   66.7               12.7  2.1
# 1434026980     14   10   10   11           Якутуголь   85.1  68.5   26.3                8.5 -3.5
# 4216008176     42   10   10   21      Южкузбассуголь   46.5  13.9   28.7                0.9 -0.1
# 4212024138     42   10   10   12        СУЭК-Кузбасс   45.0  33.8   53.0                5.1 -0.4
# 11 Производство напитков
#            region  ok1  ok2  ok3                   title      ta     of  sales  profit_before_tax    cf
# inn
# 8602060555     86   11   10   11          СУРГУТНЕФТЕГАЗ  1797.1  564.0  815.6              195.0  21.0
# 8608048498     86   11   10   11  ЛУКОЙЛ-Западная Сибирь   508.6  352.5  645.7              140.6   0.0
# 1644003838     16   11   10   11                Татнефть   474.6   94.8  344.6               86.9  -7.7
# 2437261631     24   11   10   11             ВАНКОРНЕФТЬ   417.5  345.1  215.8               43.4  -0.7
# 8903019871     89   11   10    2    Газпром добыча Надым   263.8  156.7   79.9                0.9  -0.7
# 12 Производство табачных изделий
#            region  ok1  ok2  ok3                                              title    ta   of  sales  profit_before_tax   cf
# inn
# 7530000048     75   12    0   11  ПРИАРГУНСКОЕ ПРОИЗВОДСТВЕННОЕ ГОРНО-ХИМИЧЕСКОЕ...  17.6  9.9   10.3               -1.2 -0.0
# 0302001219     03   12    0   11                                             Хиагда  13.8  9.9    1.2                0.0 -0.2
# 4506004751     45   12    0   11                                              ДАЛУР   4.3  2.5    2.0                0.6 -0.3
# 13 Производство текстильных изделий
#            region  ok1  ok2  ok3                                             title     ta    of  sales  profit_before_tax   cf
# inn
# 3127000014     31   13   10    2         Лебединский горно-обогатительный комбинат  198.6  17.0   67.7               32.0 -6.5
# 4633001577     46   13   10    2                                  Михайловский ГОК  162.7  12.1   56.3               25.6  2.5
# 2434000335     24   13   20   41                                             ПОЛЮС  140.4  23.7   61.0               30.8 -1.6
# 6615001962     66   13   10    2  ЕВРАЗ Качканарский горно-обогатительный комбинат   59.4   7.3   28.7               10.6  3.3
# 3128011788     31   13   10    2         Стойленский горно-обогатительный комбинат   54.3  21.9   39.8               24.4  0.3
# 14 Производство одежды
#            region  ok1  ok2  ok3                                              title    ta    of  sales  profit_before_tax   cf
# inn
# 5103070023     51   14   30    0                                             Апатит  45.7  27.9   45.3                7.6 -3.0
# 4713008017     47   14   12    0                                             Цемент  20.0  17.0    3.5                0.0  0.0
# 1627005779     16   14   30    0                                            Аммоний  18.1  13.6    0.1                0.0 -1.1
# 6603001252     66   14   50   26  Уральский асбестовый горно-обогатительный комб...   9.4   3.8   12.2                1.4  0.2
# 7713591359     77   14   12    0                                        Азия Цемент   8.6   6.7    0.0                0.1 -0.0
# 15 Производство кожи и изделий из кожи
#            region  ok1  ok2  ok3             title    ta    of  sales  profit_before_tax   cf
# inn
# 7830001405     78   15   96    0           Балтика  84.8  28.8   89.3               11.1  0.1
# 5045016560     50   15   84    2              Марс  61.8   7.4   65.4               14.4  0.3
# 5020037784     50   15   96    0         САН ИНБЕВ  56.2  18.0   40.6               -0.8  1.5
# 7705034202     77   15   98    2  ПепсиКо Холдингс  44.4  10.6   75.9               -3.2 -0.2
# 7713085659     77   15   51    0   Вимм-Билль-Данн  40.7   6.3   70.5                4.6 -0.2
# 16 Обработка древесины и производство изделий из дерева и пробки, кроме мебели, производство изделий из соломки и материалов для плетения
#            region  ok1  ok2  ok3                        title    ta    of  sales  profit_before_tax   cf
# inn
# 4720007247     47   16    0    0           Филип Моррис Ижора  38.5  11.1   59.3               28.9  0.1
# 7809008119     78   16    0    0  Бритиш Американ Тобакко-СПб  30.6   7.2   31.9                4.4 -0.3
# 7710064121     77   16    0    0                Лиггетт-Дукат  23.3   1.3   18.5                6.4 -0.0
# 7834005168     78   16    0    0                        Петро  17.0   9.8   40.6               13.0 -0.2
# 3443033593     34   16    0    0       Империал Тобакко Волга  11.1   4.0    8.0                1.4  0.2
# 17 Производство бумаги и бумажных изделий
#            region  ok1  ok2  ok3                                        title   ta   of  sales  profit_before_tax   cf
# inn
# 3435991384     34   17   54    3                           Газпром химволокно  5.9  3.8    0.7                0.7  0.1
# 3525087208     35   17   25    0                         ВОЛОГОДСКИЙ ТЕКСТИЛЬ  4.1  2.6    0.4               -0.3  0.0
# 7825666563     78   17   16    0  ПРЯДИЛЬНО-НИТОЧНЫЙ КОМБИНАТ ИМ. С.М. КИРОВА  3.8  2.8    1.2                0.0 -0.0
# 7722508646     77   17   53    0                    Регент Нетканые Материалы  3.6  2.9    1.2               -0.2  0.0
# 6165125323     61   17   51    0             Меринос ковры и ковровые изделия  2.9  2.3    1.1                0.0 -0.0
# 18 Деятельность полиграфическая и копирование носителей информации
#            region  ok1  ok2  ok3             title    ta   of  sales  profit_before_tax   cf
# inn
# 6166034397     61   18   22    3      Глория Джинс  10.9  1.6   22.2                2.2  0.0
# 7816043890     78   18    2    0         БТК групп   7.9  0.3    6.2                0.7  6.3
# 7724152603     77   18   21    0         Техноавиа   3.8  0.1    7.3                1.1  0.4
# 7730050504     77   18   22    2  Президент-Сервис   2.4  0.3    2.0                0.2  0.6
# 7708029923     77   18   22    0       Большевичка   2.3  0.3    0.8                0.2  0.5
# 19 Производство кокса и нефтепродуктов
#            region  ok1  ok2  ok3                          title    ta   of  sales  profit_before_tax   cf
# inn
# 6913008385     69   19   10    0  Осташковский кожевенный завод  16.9  7.1    5.8                0.1 -0.1
# 1655022254     16   19   30    0                        Спартак   4.3  0.9    0.8                0.0  0.0
# 7705032967     77   19    3    0              ПАРИЖСКАЯ КОММУНА   3.3  2.7    1.6                0.1 -0.0
# 0602065848     06   19   10    0                   РУССКАЯ КОЖА   2.5  0.2    3.1                0.0 -0.1
# 7718160370     77   19   30    0                   РАЛЬФ Рингер   1.6  0.1    2.1                0.0  0.0
# 20 Производство химических веществ и химических продуктов
#            region  ok1  ok2  ok3                                       title    ta    of  sales  profit_before_tax   cf
# inn
# 5011021227     50   20   20    1                                   Кроношпан  18.7  12.8   13.1                2.9  1.5
# 7017227500     70   20   20   13                               Партнер-Томск  12.2   9.6    2.2               -0.9 -0.1
# 4407006010     44   20   20   13                                   Кроностар   7.5   4.0   11.4                1.7  0.0
# 7838359432     78   20   30    0                                  Славянский   6.9   1.4   22.0                1.9  0.0
# 7840322535     78   20   20    1  Современные технологии обработки древесины   6.8   4.7    1.0               -1.2  0.0
# 21 Производство лекарственных средств и материалов, применяемых в медицинских целях
#            region  ok1  ok2  ok3                                       title    ta    of  sales  profit_before_tax   cf
# inn
# 7840346335     78   21   11    0                                        Илим  79.6  18.9   52.7                4.4 -0.8
# 1121003135     11   21   12    0                     Монди Сыктывкарский ЛПК  39.1  30.7   29.9                3.3 -0.2
# 4704012472     47   21    1    0                           Интернешнл Пейпер  18.6  10.3   21.0                3.0  1.9
# 2903000446     29   21   11    0  АРХАНГЕЛЬСКИЙ ЦЕЛЛЮЛОЗНО-БУМАЖНЫЙ КОМБИНАТ  17.4   6.5   17.1                1.4  0.1
# 1003000650     10   21   12    1                                   Кондопога  16.8   9.0   12.2               -1.8  0.0
# 22 Производство резиновых и пластмассовых изделий
#            region  ok1  ok2  ok3                         title    ta    of  sales  profit_before_tax   cf
# inn
# 7813352058     78   22   12    0                        Гознак  40.8  15.4   45.9                8.1  7.8
# 7705709543     77   22   22    0  Первая Образцовая типография   5.6   2.9    2.6                1.1  0.0
# 7715589549     77   22   11    1                   Просвещение   5.1   0.1    6.5                1.6  0.1
# 1655177480     16   22   22    0                ДАНАФЛЕКС-НАНО   3.5   1.8    1.8               -0.0  0.0
# 7723193075     77   22   21    0            Пушкинская площадь   3.4   2.1    2.8               -0.7  0.2
# 23 Производство прочей неметаллической минеральной продукции
#            region  ok1  ok2  ok3                      title      ta     of   sales  profit_before_tax     cf
# inn
# 7706107510     77   23   20    0                   Роснефть  2492.0  715.8  2595.7              345.6  135.8
# 0274051582     02   23   20    0                   Башнефть   339.6  100.3   489.2               57.2   -6.3
# 7727547261     77   23   20    0              СИБУР Холдинг   314.8    0.1   243.3               65.2   -1.5
# 1651044095     16   23   20    0                     ТАНЕКО   167.9  155.6    16.1                1.6   -0.3
# 5905099475     59   23   20    0  ЛУКОЙЛ-Пермнефтеоргсинтез   158.4   18.1   256.7               38.0    0.0
# 24 Производство металлургическое
#            region  ok1  ok2  ok3               title     ta    of  sales  profit_before_tax    cf
# inn
# 5911029807     59   24   15    0           Уралкалий  197.7  70.9  110.1               58.4  22.3
# 5321029508     53   24   15    0               Акрон  102.4  11.4   36.1               11.0   3.2
# 1651000010     16   24   17    0  Нижнекамскнефтехим   75.1  42.6  125.2               20.8  -1.1
# 7206032626     72   24   16    0    Тобольск-Полимер   74.3  58.8    0.3                0.7  -1.9
# 3528191736     35   24   15    0   ФОСАГРО-ЧЕРЕПОВЕЦ   59.8  18.4   27.5               11.1 -10.3
# 25 Производство готовых металлических изделий, кроме машин и оборудования
#            region  ok1  ok2  ok3                                              title    ta    of  sales  profit_before_tax   cf
# inn
# 4703073810     47   25   11    0                                      Нокиан Тайерс  21.4  16.5   18.7                3.9  0.2
# 1651049488     16   25   11    0                         Нижнекамский завод шин ЦМК  15.0  10.6    5.0                0.1  0.0
# 6340007043     63   25   23    0                                            ТАРКЕТТ  12.4   3.7   15.8                5.1  0.1
# 7601001509     76   25   11    0  Ярославский ордена Ленина и ордена Октябрьской...  12.2  10.2    7.0                0.8  0.0
# 5073007462     50   25   11    0        МИШЛЕН РУССКАЯ КОМПАНИЯ ПО ПРОИЗВОДСТВУ ШИН   9.8   2.6   18.4                1.7  0.0
# 26 Производство компьютеров, электронных и оптических изделий
#            region  ok1  ok2  ok3                                title    ta    of  sales  profit_before_tax   cf
# inn
# 1322116731     13   26   51    0                         Мордовцемент  42.7  12.2   15.3                0.2 -0.0
# 2315020195     23   26   51    0                        НОВОРОСЦЕМЕНТ  30.7  17.6   12.7                3.7  3.2
# 5022013563     50   26   51    0  Холсим (Рус) Строительные Материалы  26.2  23.1    4.1               -0.7 -0.1
# 2315076504     23   26   51    0      ВЕРХНЕБАКАНСКИЙ ЦЕМЕНТНЫЙ ЗАВОД  18.9  17.5    3.0                1.3  0.0
# 7111016601     71   26   51    0                           Тулацемент  17.2  15.4    4.0                0.1  0.0
# 27 Производство электрического оборудования
#            region  ok1  ok2  ok3                                            title     ta     of  sales  profit_before_tax    cf
# inn
# 8401005730     84   27   45    0                                НОРИЛЬСКИЙ НИКЕЛЬ  703.0  116.5  288.6               99.3   8.1
# 4823006703     48   27   10    7           Новолипецкий металлургический комбинат  471.2  153.5  240.1               29.0   8.6
# 3528000597     35   27    0    0                                       СЕВЕРСТАЛЬ  423.3   78.7  223.6               16.3   3.5
# 7414003633     74   27   10   64         Магнитогорский металлургический комбинат  328.6  151.5  243.1               11.4   0.1
# 6623000680     66   27   11    0  ЕВРАЗ Нижнетагильский металлургический комбинат  265.6   38.1  113.0               28.1  15.5
# 28 Производство машин и оборудования, не включенных в другие группировки
#            region  ok1  ok2  ok3              title    ta   of  sales  profit_before_tax   cf
# inn
# 7817005295     78   28   30    2    Ижорские заводы  26.7  3.4   10.1                0.1  0.0
# 5036040729     50   28   30    1       Зио-Подольск  15.8  1.2   11.4                0.1 -1.4
# 6325000660     63   28   52    0             ТЯЖМАШ  12.8  1.5    6.1                0.4  0.3
# 7420000133     74   28   40    1  Уральская кузница  11.3  1.4   14.8                2.0 -0.0
# 7817311895     78   28   30    2     АЭМ-технологии  10.6  0.2    5.5                0.0 -0.4
# 29 Производство автотранспортных средств, прицепов и полуприцепов
#            region  ok1  ok2  ok3                                              title     ta   of  sales  profit_before_tax   cf
# inn
# 7702080289     77   29   11   21  Силовые машины - ЗТЛ, ЛМЗ, Электросила, Энерго...  106.4  6.8   43.6               10.6 -0.3
# 5075018950     50   29   71    0                                 ЛГ Электроникс РУС   30.4  5.1   79.5                5.5  0.6
# 5050002450     50   29   24    9          открытого акционерного общества "Газпром"   26.8  0.9   79.3                0.4  1.2
# 7733015025     77   29   12    9                                     ГИДРОМАШСЕРВИС   19.5  0.1   13.4                1.9 -0.1
# 6663005798     66   29   52    0            Уральский завод тяжелого машиностроения   19.2  6.0   10.5               -2.5  0.1
# 30 Производство прочих транспортных средств и оборудования
#            region  ok1  ok2  ok3                              title   ta   of  sales  profit_before_tax   cf
# inn
# 5018037096     50   30    2    0            КРАФТВЭЙ КОРПОРЭЙШН ПЛС  3.2  0.3    6.3                0.1 -0.1
# 7804060845     78   30    2    0                           РАМЭК-ВС  3.1  0.1    8.2                0.2 -0.2
# 7842363015     78   30    2    0                       Фоксконн РУС  3.0  0.7    5.3                0.0  0.1
# 7729058675     77   30    1    9                   ИНФОСИСТЕМЫ ДЖЕТ  2.6  0.1    5.1                0.1 -0.2
# 7802170553     78   30    2    0  Специальный Технологический Центр  2.5  0.1    2.1                0.2  0.1
# 31 Производство мебели
#            region  ok1  ok2  ok3                                        title    ta   of  sales  profit_before_tax   cf
# inn
# 6313009980     63   31   20    1                       Электрощит"-ТМ Самара"  10.7  0.9   21.9                1.8  0.3
# 7801021742     78   31   30    0                                    Севкабель   8.8  1.1    0.7               -0.3 -0.0
# 7716523950     77   31   62    1       Объединенные электротехнические заводы   7.8  2.6   13.2                0.4  0.0
# 6673197337     66   31   10    1  Энергомаш(Екатеринбург) - Уралэлектротяжмаш   7.4  0.3    6.4                0.1 -0.0
# 5904184047     59   31   30    0                               Камский кабель   6.5  0.1   21.5                0.7 -0.5
# 32 Производство прочих готовых изделий
#            region  ok1  ok2  ok3                           title    ta   of  sales  profit_before_tax   cf
# inn
# 4025413896     40   32   30    2  Самсунг Электроникс Рус Калуга  36.1  5.8   64.4                6.2 -2.7
# 4703119938     47   32   30    2               Ти Пи Ви Си-Ай-Эс   6.2  0.3   10.8                0.4  0.0
# 7725593720     77   32   30    9           Нокиа Сименс Нетворкс   2.8  0.2    7.3               -0.1 -0.6
# 7806023239     78   32   30    9                 Алкатель-Лусент   1.8  0.2    4.8                0.2 -0.2
# 3328100682     33   32   30    5                   Электроприбор   1.7  0.9    1.6                0.1 -0.0
# 33 Ремонт и монтаж машин и оборудования
#            region  ok1  ok2  ok3                                              title   ta   of  sales  profit_before_tax   cf
# inn
# 7804002321     78   33   40    1                                               ЛОМО  6.8  2.2    3.4                0.0 -0.0
# 5402534361     54   33   40    1            Новосибирский приборостроительный завод  2.9  1.7    1.7                0.0 -0.1
# 6829018032     68   33   10    1                                       Росхимзащита  2.7  0.3    0.5                0.0  0.1
# 5026000300     50   33   40    0              ЛЫТКАРИНСКИЙ ЗАВОД ОПТИЧЕСКОГО СТЕКЛА  2.4  0.6    2.4                0.1  0.1
# 7203000834     72   33   10    1  Тюменский завод медицинского оборудования и ин...  2.2  0.2    0.8                0.2  0.1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-b5aa9cc62e4c> in <module>()
#       6   x = sort(industry(df, i), "ta").head(5)
#       7   if not x.empty:
# ----> 8      print (i, OKVEDv2[i])
#       9      print (x.to_string(line_width=200))
#      10
#
# KeyError: 34
